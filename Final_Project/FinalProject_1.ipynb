# %% [markdown]
# # Final Project

# %% [markdown]
# Find all QSO in SDSS DR18 in my given redshift ratio.

# %%
import os
import pandas as pd
from astroquery.sdss import SDSS
from astroquery.gaia import Gaia

# %%
query1 = """
SELECT COUNT(*)
FROM SpecObj AS s
WHERE
s.Class = 'QSO'  
AND s.z > 0 AND s.z < 1.1
"""

# %%
QSO_df = SDSS.query_sql(query1).to_pandas()
QSO_df
# Out:
#    Column1
# 0   295722

# %%
query2 = """
SELECT bestObjID
FROM SpecObj AS s
WHERE
s.Class = 'QSO'  
AND s.z > 0 AND s.z < 1.1
"""

# %%
QSO = SDSS.query_sql(query2).to_pandas()

# %% [markdown]
# Cross-match them with Gaia DR3. For cross match, use the Gaia additional catalog with sources already matched with SDSS DR13.

# %%
# Configuration
batch_size = 1000  # Number of IDs per batch
output_file = "gaia_results_all_batches.csv"  # Output file for results
failed_batches_file = "failed_batches.txt"  # Log file for failed batches
max_retries = 3  # Number of retries for failed batches

# Main batch processing loop
for i in range(0, len(QSO), batch_size):
    # Create the batch query
    batch_ids = "','".join(map(str, QSO['bestObjID'][i:i + batch_size]))
    
    query3 = f"""
    SELECT s.source_id, s.original_ext_source_id
    FROM gaiadr3.sdssdr13_best_neighbour AS s
    WHERE s.original_ext_source_id IN ('{batch_ids}')
    """
    
    retries = 0
    success = False

    while retries < max_retries and not success:
        try:
            print(f"Processing batch {i // batch_size + 1} ({i} to {i + batch_size} IDs)... Attempt {retries + 1}")
            job = Gaia.launch_job(query3)
            batch_results = job.get_results().to_pandas()
            print(f"Batch {i // batch_size + 1} returned {len(batch_results)} rows.")
            
            # Reload existing results
            existing_results = pd.read_csv(output_file) if os.path.exists(output_file) else pd.DataFrame()
            
            # Combine results and remove duplicates
            combined_results = pd.concat([existing_results, batch_results], ignore_index=True).drop_duplicates()
            
            # Save the updated results
            combined_results.to_csv(output_file, index=False)
            print(f"Batch {i // batch_size + 1} completed. Total rows saved: {len(combined_results)}")
            
            success = True  # Mark batch as successful
        except Exception as e:
            retries += 1
            print(f"Error processing batch {i} to {i + batch_size}: {e}")
    
    if not success:
        # Log failed batch to file
        with open(failed_batches_file, "a") as log_file:
            log_file.write(f"{i},{i + batch_size}\n")
        print(f"Batch {i} to {i + batch_size} failed after {max_retries} retries. Moving to the next batch.")

# Reprocess failed batches
print("Reprocessing failed batches...")
try:
    with open(failed_batches_file, "r") as log_file:
        failed_batches = log_file.readlines()
except FileNotFoundError:
    failed_batches = []

for batch_range in failed_batches:
    start, end = map(int, batch_range.strip().split(","))
    batch_ids = "','".join(map(str, QSO['bestObjID'][start:end]))
    query3 = f"""
    SELECT s.source_id, s.original_ext_source_id
    FROM gaiadr3.sdssdr13_best_neighbour AS s
    WHERE s.original_ext_source_id IN ('{batch_ids}')
    """
    try:
        print(f"Reprocessing batch {start} to {end}...")
        job = Gaia.launch_job(query3)
        batch_results = job.get_results().to_pandas()
        
        # Reload existing results
        existing_results = pd.read_csv(output_file) if os.path.exists(output_file) else pd.DataFrame()
        
        # Combine results and remove duplicates
        combined_results = pd.concat([existing_results, batch_results], ignore_index=True).drop_duplicates()
        
        # Save the updated results
        combined_results.to_csv(output_file, index=False)
        print(f"Batch {start} to {end} reprocessed successfully. Total rows saved: {len(combined_results)}")
        
        # Remove successfully reprocessed batch from log
        with open(failed_batches_file, "r") as log_file:
            lines = log_file.readlines()
        with open(failed_batches_file, "w") as log_file:
            log_file.writelines(line for line in lines if line.strip() != f"{start},{end}")
    except Exception as e:
        print(f"Failed to reprocess batch {start} to {end}: {e}")

# Final message
print("All processing completed.")
# Out:
# Processing batch 1 (0 to 1000 IDs)... Attempt 1
# Batch 1 returned 920 rows.
# Batch 1 completed. Total rows saved: 920
# Processing batch 2 (1000 to 2000 IDs)... Attempt 1
# Error processing batch 1000 to 2000: [Errno 54] Connection reset by peer
# Processing batch 2 (1000 to 2000 IDs)... Attempt 2
# Batch 2 returned 956 rows.
# Batch 2 completed. Total rows saved: 1876
# Processing batch 3 (2000 to 3000 IDs)... Attempt 1
# Batch 3 returned 960 rows.
# Batch 3 completed. Total rows saved: 2836
# Processing batch 4 (3000 to 4000 IDs)... Attempt 1
# Batch 4 returned 945 rows.
# Batch 4 completed. Total rows saved: 3781
# Processing batch 5 (4000 to 5000 IDs)... Attempt 1
# Batch 5 returned 906 rows.
# Batch 5 completed. Total rows saved: 4687
# Processing batch 6 (5000 to 6000 IDs)... Attempt 1
# Error processing batch 5000 to 6000: [Errno 54] Connection reset by peer
# Processing batch 6 (5000 to 6000 IDs)... Attempt 2
# Batch 6 returned 882 rows.
# Batch 6 completed. Total rows saved: 5569
# Processing batch 7 (6000 to 7000 IDs)... Attempt 1
# Batch 7 returned 893 rows.
# Batch 7 completed. Total rows saved: 6462
# Processing batch 8 (7000 to 8000 IDs)... Attempt 1
# Batch 8 returned 900 rows.
# Batch 8 completed. Total rows saved: 7362
# Processing batch 9 (8000 to 9000 IDs)... Attempt 1
# Error processing batch 8000 to 9000: [Errno 54] Connection reset by peer
# Processing batch 9 (8000 to 9000 IDs)... Attempt 2
# Batch 9 returned 896 rows.
# Batch 9 completed. Total rows saved: 8258
# Processing batch 10 (9000 to 10000 IDs)... Attempt 1
# Batch 10 returned 893 rows.
# Batch 10 completed. Total rows saved: 9151
# Processing batch 11 (10000 to 11000 IDs)... Attempt 1
# Batch 11 returned 880 rows.
# Batch 11 completed. Total rows saved: 10031
# Processing batch 12 (11000 to 12000 IDs)... Attempt 1
# Error processing batch 11000 to 12000: [Errno 54] Connection reset by peer
# Processing batch 12 (11000 to 12000 IDs)... Attempt 2
# Batch 12 returned 868 rows.
# Batch 12 completed. Total rows saved: 10899
# Processing batch 13 (12000 to 13000 IDs)... Attempt 1
# Batch 13 returned 886 rows.
# Batch 13 completed. Total rows saved: 11785
# Processing batch 14 (13000 to 14000 IDs)... Attempt 1
# Batch 14 returned 893 rows.
# Batch 14 completed. Total rows saved: 12678
# Processing batch 15 (14000 to 15000 IDs)... Attempt 1
# Batch 15 returned 856 rows.
# Batch 15 completed. Total rows saved: 13534
# Processing batch 16 (15000 to 16000 IDs)... Attempt 1
# Batch 16 returned 847 rows.
# Batch 16 completed. Total rows saved: 14381
# Processing batch 17 (16000 to 17000 IDs)... Attempt 1
# Batch 17 returned 825 rows.
# Batch 17 completed. Total rows saved: 15206
# Processing batch 18 (17000 to 18000 IDs)... Attempt 1
# Batch 18 returned 827 rows.
# Batch 18 completed. Total rows saved: 16033
# Processing batch 19 (18000 to 19000 IDs)... Attempt 1
# Batch 19 returned 830 rows.
# Batch 19 completed. Total rows saved: 16863
# Processing batch 20 (19000 to 20000 IDs)... Attempt 1
# Batch 20 returned 809 rows.
# Batch 20 completed. Total rows saved: 17672
# Processing batch 21 (20000 to 21000 IDs)... Attempt 1
# Batch 21 returned 789 rows.
# Batch 21 completed. Total rows saved: 18461
# Processing batch 22 (21000 to 22000 IDs)... Attempt 1
# Batch 22 returned 741 rows.
# Batch 22 completed. Total rows saved: 19202
# Processing batch 23 (22000 to 23000 IDs)... Attempt 1
# Batch 23 returned 704 rows.
# Batch 23 completed. Total rows saved: 19906
# Processing batch 24 (23000 to 24000 IDs)... Attempt 1
# Batch 24 returned 711 rows.
# Batch 24 completed. Total rows saved: 20617
# Processing batch 25 (24000 to 25000 IDs)... Attempt 1
# Batch 25 returned 696 rows.
# Batch 25 completed. Total rows saved: 21313
# Processing batch 26 (25000 to 26000 IDs)... Attempt 1
# Batch 26 returned 669 rows.
# Batch 26 completed. Total rows saved: 21982
# Processing batch 27 (26000 to 27000 IDs)... Attempt 1
# Batch 27 returned 718 rows.
# Batch 27 completed. Total rows saved: 22700
# Processing batch 28 (27000 to 28000 IDs)... Attempt 1
# Batch 28 returned 678 rows.
# Batch 28 completed. Total rows saved: 23378
# Processing batch 29 (28000 to 29000 IDs)... Attempt 1
# Batch 29 returned 636 rows.
# Batch 29 completed. Total rows saved: 24014
# Processing batch 30 (29000 to 30000 IDs)... Attempt 1
# Batch 30 returned 627 rows.
# Batch 30 completed. Total rows saved: 24641
# Processing batch 31 (30000 to 31000 IDs)... Attempt 1
# Batch 31 returned 604 rows.
# Batch 31 completed. Total rows saved: 25245
# Processing batch 32 (31000 to 32000 IDs)... Attempt 1
# Batch 32 returned 576 rows.
# Batch 32 completed. Total rows saved: 25821
# Processing batch 33 (32000 to 33000 IDs)... Attempt 1
# Batch 33 returned 558 rows.
# Batch 33 completed. Total rows saved: 26379
# Processing batch 34 (33000 to 34000 IDs)... Attempt 1
# Batch 34 returned 566 rows.
# Batch 34 completed. Total rows saved: 26945
# Processing batch 35 (34000 to 35000 IDs)... Attempt 1
# Batch 35 returned 642 rows.
# Batch 35 completed. Total rows saved: 27587
# Processing batch 36 (35000 to 36000 IDs)... Attempt 1
# Batch 36 returned 629 rows.
# Batch 36 completed. Total rows saved: 28216
# Processing batch 37 (36000 to 37000 IDs)... Attempt 1
# Batch 37 returned 597 rows.
# Batch 37 completed. Total rows saved: 28813
# Processing batch 38 (37000 to 38000 IDs)... Attempt 1
# Batch 38 returned 654 rows.
# Batch 38 completed. Total rows saved: 29467
# Processing batch 39 (38000 to 39000 IDs)... Attempt 1
# Batch 39 returned 656 rows.
# Batch 39 completed. Total rows saved: 30123
# Processing batch 40 (39000 to 40000 IDs)... Attempt 1
# Error processing batch 39000 to 40000: Error 400:
# Cannot parse query '
#     SELECT  TOP 2000 s.source_id, s.original_ext_source_id
#     FROM gaiadr3.sdssdr13_best_neighbour AS s
#     WHERE s.original_ext_source_id IN ('1237657634334835072','1237662267542012319','1237651251487900274','1237659324960211195','1237654652566503546','1237660636524708256','1237654653101343069','1237665129620308479','1237667255629119662','1237662300828467504','1237678776322556207','1237667429566054581','1237662300824469756','1237654627322168288','1237662268068462908','1237661872952574220','1237659131134214582','1237661464921244377','1237667782275891753','1237664131016950460','1237678889061908586','1237666246284280379','1237680481416577466','1237654872139891348','1237655463785005411','1237651272435368101','1237658491208204335','1237666214071107628','1237661433779716387','1237657591395254295','1237658203976302979','1237657594613399851','1237667254555050674','1237673310433509497','1237651252561248580','1237654953739420111','1237667253452079520','1237662225132224902','1237659325487251605','1237680316061909721','1237648720718004591','1237651271354548450','1237662198288286352','1237661434846708048','1237679477466923341','1237656494033535367','1237665126927630690','1237661353778086170','1237658801493836148','1237664835934814552','1237665549962117309','1237663456704922504','1237662342166741315','1237657776618144080','1237652944248963911','1237664294218826091','1237664674328805504','1237663239272333554','1237659324954707023','1237672764974891858','1237653651309854753','1237658800956637446','1237651537650057421','1237654949987615261','1237661871873196159','1237658303278940501','1237678541162414219','1237655550205362306','1237679997697786163','1237659324951036319','1237654380904120613','1237671260664430775','1237680530276156215','1237667915422171898','1237663530256892186','1237678881554759944','1237655369291333734','1237661387073978631','1237671934967677594','1237658203958280352','1237660024523063599','1237667255621910584','1237666302165057812','1237667211059593712','1237651539255492721','1237678879963545952','1237678879945064753','1237648722301813423','1237667911674102832','1237662337328153305','1237665370119995609','1237662683068957214','1237654605314654669','1237667735034724518','1237669681187979525','1237651496834040372','1237662641194467652','1237652944239460798','1237667254015689297','1237662225699635600','1237680297812558561','1237679035087848037','1237663787949359571','1237665571439640686','1237657595150730019','1237666274734833778','1237651496833319316','1237663542605775539','1237660241387389864','1237654606408646862','1237662196141785100','1237664852578271284','1237665571440034178','1237661850937458929','1237662195614810281','1237678789198741893','1237661872397549691','1237680504505959277','1237679541890908492','1237663275778310611','1237679998230266306','1237654400762970675','1237680297279816125','1237667734500803030','1237661972805255264','1237667485916791278','1237680298880139873','1237678581443395940','1237654879128716017','1237665330927436009','1237654948914069849','1237669766552748153','1237678661974884882','1237651753483567316','1237671934428119472','1237667254003564727','1237667536390718130','1237662698102063594','1237661388676595985','1237666214609289428','1237651273498362194','1237678879414419610','1237679322323943687','1237679437739524340','1237660634389414033','1237656906342924586','1237654881798783366','1237657591935008965','1237665550498398359','1237664819284476000','1237663784209351207','1237676442534347258','1237662662134202517','1237667429553471891','1237655130373947663','1237680099703849318','1237680306403344583','1237648721227481751','1237662662144426030','1237650805340766528','1237678789736726859','1237662307806871751','1237678617409946006','1237680241986830944','1237659162817594047','1237680531352322088','1237651272961425942','1237661966352056625','1237678596484366509','1237665097389834914','1237667537464393850','1237650371556016145','1237661383314637158','1237679254665494546','1237678622244209159','1237666214075170957','1237678541162218096','1237667253990523942','1237667536936239234','1237670014583374119',' ...
#     ' for job '1733078957001O': 4 unresolved identifiers: sdssdr13_best_neighbour [l.3 c.10 - l.3 c.41], source_id [l.2 c.22 - l.2 c.33], original_ext_source_id [l.2 c.35 - l.2 c.59], original_ext_source_id [l.4 c.11 - l.4 c.35] !
#  - Unknown table "gaiadr3.sdssdr13_best_neighbour" (alias s) !
#  - Unknown column "s.source_id" !
#  - Unknown column "s.original_ext_source_id" !
#  - Unknown column "s.original_ext_source_id" !
#
# Processing batch 40 (39000 to 40000 IDs)... Attempt 2
# Batch 40 returned 624 rows.
# Batch 40 completed. Total rows saved: 30747
# Processing batch 41 (40000 to 41000 IDs)... Attempt 1
# Batch 41 returned 685 rows.
# Batch 41 completed. Total rows saved: 31432
# Processing batch 42 (41000 to 42000 IDs)... Attempt 1
# Batch 42 returned 649 rows.
# Batch 42 completed. Total rows saved: 32081
# Processing batch 43 (42000 to 43000 IDs)... Attempt 1
# Batch 43 returned 627 rows.
# Batch 43 completed. Total rows saved: 32708
# Processing batch 44 (43000 to 44000 IDs)... Attempt 1
# Batch 44 returned 669 rows.
# Batch 44 completed. Total rows saved: 33377
# Processing batch 45 (44000 to 45000 IDs)... Attempt 1
# Batch 45 returned 640 rows.
# Batch 45 completed. Total rows saved: 34017
# Processing batch 46 (45000 to 46000 IDs)... Attempt 1
# Batch 46 returned 640 rows.
# Batch 46 completed. Total rows saved: 34657
# Processing batch 47 (46000 to 47000 IDs)... Attempt 1
# Batch 47 returned 681 rows.
# Batch 47 completed. Total rows saved: 35338
# Processing batch 48 (47000 to 48000 IDs)... Attempt 1
# Batch 48 returned 658 rows.
# Batch 48 completed. Total rows saved: 35996
# Processing batch 49 (48000 to 49000 IDs)... Attempt 1
# Batch 49 returned 679 rows.
# Batch 49 completed. Total rows saved: 36675
# Processing batch 50 (49000 to 50000 IDs)... Attempt 1
# Batch 50 returned 632 rows.
# Batch 50 completed. Total rows saved: 37307
# Processing batch 51 (50000 to 51000 IDs)... Attempt 1
# Batch 51 returned 613 rows.
# Batch 51 completed. Total rows saved: 37920
# Processing batch 52 (51000 to 52000 IDs)... Attempt 1
# Batch 52 returned 620 rows.
# Batch 52 completed. Total rows saved: 38540
# Processing batch 53 (52000 to 53000 IDs)... Attempt 1
# Batch 53 returned 671 rows.
# Batch 53 completed. Total rows saved: 39211
# Processing batch 54 (53000 to 54000 IDs)... Attempt 1
# Batch 54 returned 643 rows.
# Batch 54 completed. Total rows saved: 39854
# Processing batch 55 (54000 to 55000 IDs)... Attempt 1
# Batch 55 returned 660 rows.
# Batch 55 completed. Total rows saved: 40514
# Processing batch 56 (55000 to 56000 IDs)... Attempt 1
# Batch 56 returned 627 rows.
# Batch 56 completed. Total rows saved: 41141
# Processing batch 57 (56000 to 57000 IDs)... Attempt 1
# Batch 57 returned 659 rows.
# Batch 57 completed. Total rows saved: 41800
# Processing batch 58 (57000 to 58000 IDs)... Attempt 1
# Batch 58 returned 653 rows.
# Batch 58 completed. Total rows saved: 42453
# Processing batch 59 (58000 to 59000 IDs)... Attempt 1
# Batch 59 returned 709 rows.
# Batch 59 completed. Total rows saved: 43162
# Processing batch 60 (59000 to 60000 IDs)... Attempt 1
# Batch 60 returned 671 rows.
# Batch 60 completed. Total rows saved: 43833
# Processing batch 61 (60000 to 61000 IDs)... Attempt 1
# Batch 61 returned 664 rows.
# Batch 61 completed. Total rows saved: 44497
# Processing batch 62 (61000 to 62000 IDs)... Attempt 1
# Batch 62 returned 682 rows.
# Batch 62 completed. Total rows saved: 45179
# Processing batch 63 (62000 to 63000 IDs)... Attempt 1
# Batch 63 returned 674 rows.
# Batch 63 completed. Total rows saved: 45853
# Processing batch 64 (63000 to 64000 IDs)... Attempt 1
# Batch 64 returned 676 rows.
# Batch 64 completed. Total rows saved: 46529
# Processing batch 65 (64000 to 65000 IDs)... Attempt 1
# Batch 65 returned 687 rows.
# Batch 65 completed. Total rows saved: 47216
# Processing batch 66 (65000 to 66000 IDs)... Attempt 1
# Batch 66 returned 661 rows.
# Batch 66 completed. Total rows saved: 47877
# Processing batch 67 (66000 to 67000 IDs)... Attempt 1
# Batch 67 returned 684 rows.
# Batch 67 completed. Total rows saved: 48561
# Processing batch 68 (67000 to 68000 IDs)... Attempt 1
# Batch 68 returned 648 rows.
# Batch 68 completed. Total rows saved: 49209
# Processing batch 69 (68000 to 69000 IDs)... Attempt 1
# Batch 69 returned 689 rows.
# Batch 69 completed. Total rows saved: 49898
# Processing batch 70 (69000 to 70000 IDs)... Attempt 1
# Batch 70 returned 708 rows.
# Batch 70 completed. Total rows saved: 50606
# Processing batch 71 (70000 to 71000 IDs)... Attempt 1
# Batch 71 returned 706 rows.
# Batch 71 completed. Total rows saved: 51312
# Processing batch 72 (71000 to 72000 IDs)... Attempt 1
# Batch 72 returned 690 rows.
# Batch 72 completed. Total rows saved: 52002
# Processing batch 73 (72000 to 73000 IDs)... Attempt 1
# Batch 73 returned 636 rows.
# Batch 73 completed. Total rows saved: 52638
# Processing batch 74 (73000 to 74000 IDs)... Attempt 1
# Batch 74 returned 693 rows.
# Batch 74 completed. Total rows saved: 53331
# Processing batch 75 (74000 to 75000 IDs)... Attempt 1
# Batch 75 returned 664 rows.
# Batch 75 completed. Total rows saved: 53995
# Processing batch 76 (75000 to 76000 IDs)... Attempt 1
# Batch 76 returned 677 rows.
# Batch 76 completed. Total rows saved: 54672
# Processing batch 77 (76000 to 77000 IDs)... Attempt 1
# Batch 77 returned 679 rows.
# Batch 77 completed. Total rows saved: 55351
# Processing batch 78 (77000 to 78000 IDs)... Attempt 1
# Batch 78 returned 651 rows.
# Batch 78 completed. Total rows saved: 56002
# Processing batch 79 (78000 to 79000 IDs)... Attempt 1
# Batch 79 returned 667 rows.
# Batch 79 completed. Total rows saved: 56669
# Processing batch 80 (79000 to 80000 IDs)... Attempt 1
# Batch 80 returned 648 rows.
# Batch 80 completed. Total rows saved: 57317
# Processing batch 81 (80000 to 81000 IDs)... Attempt 1
# Batch 81 returned 659 rows.
# Batch 81 completed. Total rows saved: 57976
# Processing batch 82 (81000 to 82000 IDs)... Attempt 1
# Batch 82 returned 684 rows.
# Batch 82 completed. Total rows saved: 58660
# Processing batch 83 (82000 to 83000 IDs)... Attempt 1
# Batch 83 returned 637 rows.
# Batch 83 completed. Total rows saved: 59297
# Processing batch 84 (83000 to 84000 IDs)... Attempt 1
# Batch 84 returned 688 rows.
# Batch 84 completed. Total rows saved: 59985
# Processing batch 85 (84000 to 85000 IDs)... Attempt 1
# Batch 85 returned 691 rows.
# Batch 85 completed. Total rows saved: 60676
# Processing batch 86 (85000 to 86000 IDs)... Attempt 1
# Batch 86 returned 687 rows.
# Batch 86 completed. Total rows saved: 61363
# Processing batch 87 (86000 to 87000 IDs)... Attempt 1
# Batch 87 returned 690 rows.
# Batch 87 completed. Total rows saved: 62053
# Processing batch 88 (87000 to 88000 IDs)... Attempt 1
# Batch 88 returned 682 rows.
# Batch 88 completed. Total rows saved: 62735
# Processing batch 89 (88000 to 89000 IDs)... Attempt 1
# Batch 89 returned 654 rows.
# Batch 89 completed. Total rows saved: 63389
# Processing batch 90 (89000 to 90000 IDs)... Attempt 1
# Batch 90 returned 672 rows.
# Batch 90 completed. Total rows saved: 64061
# Processing batch 91 (90000 to 91000 IDs)... Attempt 1
# Batch 91 returned 659 rows.
# Batch 91 completed. Total rows saved: 64720
# Processing batch 92 (91000 to 92000 IDs)... Attempt 1
# Batch 92 returned 634 rows.
# Batch 92 completed. Total rows saved: 65354
# Processing batch 93 (92000 to 93000 IDs)... Attempt 1
# Batch 93 returned 656 rows.
# Batch 93 completed. Total rows saved: 66010
# Processing batch 94 (93000 to 94000 IDs)... Attempt 1
# Batch 94 returned 698 rows.
# Batch 94 completed. Total rows saved: 66708
# Processing batch 95 (94000 to 95000 IDs)... Attempt 1
# Batch 95 returned 677 rows.
# Batch 95 completed. Total rows saved: 67385
# Processing batch 96 (95000 to 96000 IDs)... Attempt 1
# Batch 96 returned 690 rows.
# Batch 96 completed. Total rows saved: 68075
# Processing batch 97 (96000 to 97000 IDs)... Attempt 1
# Batch 97 returned 681 rows.
# Batch 97 completed. Total rows saved: 68756
# Processing batch 98 (97000 to 98000 IDs)... Attempt 1
# Batch 98 returned 693 rows.
# Batch 98 completed. Total rows saved: 69449
# Processing batch 99 (98000 to 99000 IDs)... Attempt 1
# Batch 99 returned 660 rows.
# Batch 99 completed. Total rows saved: 70109
# Processing batch 100 (99000 to 100000 IDs)... Attempt 1
# Batch 100 returned 667 rows.
# Batch 100 completed. Total rows saved: 70776
# Processing batch 101 (100000 to 101000 IDs)... Attempt 1
# Batch 101 returned 641 rows.
# Batch 101 completed. Total rows saved: 71417
# Processing batch 102 (101000 to 102000 IDs)... Attempt 1
# Batch 102 returned 652 rows.
# Batch 102 completed. Total rows saved: 72069
# Processing batch 103 (102000 to 103000 IDs)... Attempt 1
# Batch 103 returned 677 rows.
# Batch 103 completed. Total rows saved: 72746
# Processing batch 104 (103000 to 104000 IDs)... Attempt 1
# Batch 104 returned 663 rows.
# Batch 104 completed. Total rows saved: 73409
# Processing batch 105 (104000 to 105000 IDs)... Attempt 1
# Batch 105 returned 707 rows.
# Batch 105 completed. Total rows saved: 74116
# Processing batch 106 (105000 to 106000 IDs)... Attempt 1
# Batch 106 returned 694 rows.
# Batch 106 completed. Total rows saved: 74810
# Processing batch 107 (106000 to 107000 IDs)... Attempt 1
# Batch 107 returned 680 rows.
# Batch 107 completed. Total rows saved: 75490
# Processing batch 108 (107000 to 108000 IDs)... Attempt 1
# Batch 108 returned 646 rows.
# Batch 108 completed. Total rows saved: 76136
# Processing batch 109 (108000 to 109000 IDs)... Attempt 1
# Batch 109 returned 677 rows.
# Batch 109 completed. Total rows saved: 76813
# Processing batch 110 (109000 to 110000 IDs)... Attempt 1
# Batch 110 returned 670 rows.
# Batch 110 completed. Total rows saved: 77483
# Processing batch 111 (110000 to 111000 IDs)... Attempt 1
# Batch 111 returned 676 rows.
# Batch 111 completed. Total rows saved: 78159
# Processing batch 112 (111000 to 112000 IDs)... Attempt 1
# Batch 112 returned 674 rows.
# Batch 112 completed. Total rows saved: 78833
# Processing batch 113 (112000 to 113000 IDs)... Attempt 1
# Batch 113 returned 692 rows.
# Batch 113 completed. Total rows saved: 79525
# Processing batch 114 (113000 to 114000 IDs)... Attempt 1
# Batch 114 returned 696 rows.
# Batch 114 completed. Total rows saved: 80221
# Processing batch 115 (114000 to 115000 IDs)... Attempt 1
# Batch 115 returned 687 rows.
# Batch 115 completed. Total rows saved: 80908
# Processing batch 116 (115000 to 116000 IDs)... Attempt 1
# Batch 116 returned 702 rows.
# Batch 116 completed. Total rows saved: 81610
# Processing batch 117 (116000 to 117000 IDs)... Attempt 1
# Batch 117 returned 672 rows.
# Batch 117 completed. Total rows saved: 82282
# Processing batch 118 (117000 to 118000 IDs)... Attempt 1
# Batch 118 returned 735 rows.
# Batch 118 completed. Total rows saved: 83017
# Processing batch 119 (118000 to 119000 IDs)... Attempt 1
# Batch 119 returned 688 rows.
# Batch 119 completed. Total rows saved: 83705
# Processing batch 120 (119000 to 120000 IDs)... Attempt 1
# Batch 120 returned 692 rows.
# Batch 120 completed. Total rows saved: 84397
# Processing batch 121 (120000 to 121000 IDs)... Attempt 1
# Batch 121 returned 680 rows.
# Batch 121 completed. Total rows saved: 85077
# Processing batch 122 (121000 to 122000 IDs)... Attempt 1
# Batch 122 returned 680 rows.
# Batch 122 completed. Total rows saved: 85757
# Processing batch 123 (122000 to 123000 IDs)... Attempt 1
# Error processing batch 122000 to 123000: [Errno 54] Connection reset by peer
# Processing batch 123 (122000 to 123000 IDs)... Attempt 2
# Batch 123 returned 701 rows.
# Batch 123 completed. Total rows saved: 86458
# Processing batch 124 (123000 to 124000 IDs)... Attempt 1
# Batch 124 returned 707 rows.
# Batch 124 completed. Total rows saved: 87165
# Processing batch 125 (124000 to 125000 IDs)... Attempt 1
# Batch 125 returned 717 rows.
# Batch 125 completed. Total rows saved: 87882
# Processing batch 126 (125000 to 126000 IDs)... Attempt 1
# Batch 126 returned 707 rows.
# Batch 126 completed. Total rows saved: 88589
# Processing batch 127 (126000 to 127000 IDs)... Attempt 1
# Batch 127 returned 707 rows.
# Batch 127 completed. Total rows saved: 89296
# Processing batch 128 (127000 to 128000 IDs)... Attempt 1
# Batch 128 returned 682 rows.
# Batch 128 completed. Total rows saved: 89978
# Processing batch 129 (128000 to 129000 IDs)... Attempt 1
# Batch 129 returned 709 rows.
# Batch 129 completed. Total rows saved: 90687
# Processing batch 130 (129000 to 130000 IDs)... Attempt 1
# Error processing batch 129000 to 130000: [Errno 54] Connection reset by peer
# Processing batch 130 (129000 to 130000 IDs)... Attempt 2
# Batch 130 returned 712 rows.
# Batch 130 completed. Total rows saved: 91399
# Processing batch 131 (130000 to 131000 IDs)... Attempt 1
# Batch 131 returned 674 rows.
# Batch 131 completed. Total rows saved: 92073
# Processing batch 132 (131000 to 132000 IDs)... Attempt 1
# Batch 132 returned 712 rows.
# Batch 132 completed. Total rows saved: 92785
# Processing batch 133 (132000 to 133000 IDs)... Attempt 1
# Batch 133 returned 688 rows.
# Batch 133 completed. Total rows saved: 93473
# Processing batch 134 (133000 to 134000 IDs)... Attempt 1
# Batch 134 returned 702 rows.
# Batch 134 completed. Total rows saved: 94175
# Processing batch 135 (134000 to 135000 IDs)... Attempt 1
# Batch 135 returned 685 rows.
# Batch 135 completed. Total rows saved: 94860
# Processing batch 136 (135000 to 136000 IDs)... Attempt 1
# Batch 136 returned 706 rows.
# Batch 136 completed. Total rows saved: 95566
# Processing batch 137 (136000 to 137000 IDs)... Attempt 1
# Batch 137 returned 722 rows.
# Batch 137 completed. Total rows saved: 96288
# Processing batch 138 (137000 to 138000 IDs)... Attempt 1
# Error processing batch 137000 to 138000: [Errno 54] Connection reset by peer
# Processing batch 138 (137000 to 138000 IDs)... Attempt 2
# Batch 138 returned 684 rows.
# Batch 138 completed. Total rows saved: 96972
# Processing batch 139 (138000 to 139000 IDs)... Attempt 1
# Batch 139 returned 722 rows.
# Batch 139 completed. Total rows saved: 97694
# Processing batch 140 (139000 to 140000 IDs)... Attempt 1
# Batch 140 returned 676 rows.
# Batch 140 completed. Total rows saved: 98370
# Processing batch 141 (140000 to 141000 IDs)... Attempt 1
# Batch 141 returned 672 rows.
# Batch 141 completed. Total rows saved: 99042
# Processing batch 142 (141000 to 142000 IDs)... Attempt 1
# Batch 142 returned 717 rows.
# Batch 142 completed. Total rows saved: 99759
# Processing batch 143 (142000 to 143000 IDs)... Attempt 1
# Batch 143 returned 692 rows.
# Batch 143 completed. Total rows saved: 100451
# Processing batch 144 (143000 to 144000 IDs)... Attempt 1
# Batch 144 returned 687 rows.
# Batch 144 completed. Total rows saved: 101138
# Processing batch 145 (144000 to 145000 IDs)... Attempt 1
# Batch 145 returned 692 rows.
# Batch 145 completed. Total rows saved: 101830
# Processing batch 146 (145000 to 146000 IDs)... Attempt 1
# Batch 146 returned 665 rows.
# Batch 146 completed. Total rows saved: 102495
# Processing batch 147 (146000 to 147000 IDs)... Attempt 1
# Error processing batch 146000 to 147000: [Errno 54] Connection reset by peer
# Processing batch 147 (146000 to 147000 IDs)... Attempt 2
# Batch 147 returned 731 rows.
# Batch 147 completed. Total rows saved: 103226
# Processing batch 148 (147000 to 148000 IDs)... Attempt 1
# Batch 148 returned 706 rows.
# Batch 148 completed. Total rows saved: 103932
# Processing batch 149 (148000 to 149000 IDs)... Attempt 1
# Batch 149 returned 698 rows.
# Batch 149 completed. Total rows saved: 104630
# Processing batch 150 (149000 to 150000 IDs)... Attempt 1
# Batch 150 returned 672 rows.
# Batch 150 completed. Total rows saved: 105302
# Processing batch 151 (150000 to 151000 IDs)... Attempt 1
# Batch 151 returned 677 rows.
# Batch 151 completed. Total rows saved: 105979
# Processing batch 152 (151000 to 152000 IDs)... Attempt 1
# Batch 152 returned 725 rows.
# Batch 152 completed. Total rows saved: 106704
# Processing batch 153 (152000 to 153000 IDs)... Attempt 1
# Batch 153 returned 671 rows.
# Batch 153 completed. Total rows saved: 107375
# Processing batch 154 (153000 to 154000 IDs)... Attempt 1
# Batch 154 returned 637 rows.
# Batch 154 completed. Total rows saved: 108012
# Processing batch 155 (154000 to 155000 IDs)... Attempt 1
# Batch 155 returned 681 rows.
# Batch 155 completed. Total rows saved: 108693
# Processing batch 156 (155000 to 156000 IDs)... Attempt 1
# Batch 156 returned 691 rows.
# Batch 156 completed. Total rows saved: 109384
# Processing batch 157 (156000 to 157000 IDs)... Attempt 1
# Batch 157 returned 708 rows.
# Batch 157 completed. Total rows saved: 110092
# Processing batch 158 (157000 to 158000 IDs)... Attempt 1
# Batch 158 returned 694 rows.
# Batch 158 completed. Total rows saved: 110786
# Processing batch 159 (158000 to 159000 IDs)... Attempt 1
# Batch 159 returned 695 rows.
# Batch 159 completed. Total rows saved: 111481
# Processing batch 160 (159000 to 160000 IDs)... Attempt 1
# Batch 160 returned 715 rows.
# Batch 160 completed. Total rows saved: 112196
# Processing batch 161 (160000 to 161000 IDs)... Attempt 1
# Batch 161 returned 680 rows.
# Batch 161 completed. Total rows saved: 112876
# Processing batch 162 (161000 to 162000 IDs)... Attempt 1
# Batch 162 returned 682 rows.
# Batch 162 completed. Total rows saved: 113558
# Processing batch 163 (162000 to 163000 IDs)... Attempt 1
# Batch 163 returned 715 rows.
# Batch 163 completed. Total rows saved: 114273
# Processing batch 164 (163000 to 164000 IDs)... Attempt 1
# Batch 164 returned 667 rows.
# Batch 164 completed. Total rows saved: 114940
# Processing batch 165 (164000 to 165000 IDs)... Attempt 1
# Batch 165 returned 691 rows.
# Batch 165 completed. Total rows saved: 115631
# Processing batch 166 (165000 to 166000 IDs)... Attempt 1
# Batch 166 returned 675 rows.
# Batch 166 completed. Total rows saved: 116306
# Processing batch 167 (166000 to 167000 IDs)... Attempt 1
# Batch 167 returned 670 rows.
# Batch 167 completed. Total rows saved: 116976
# Processing batch 168 (167000 to 168000 IDs)... Attempt 1
# Error processing batch 167000 to 168000: [Errno 54] Connection reset by peer
# Processing batch 168 (167000 to 168000 IDs)... Attempt 2
# Batch 168 returned 706 rows.
# Batch 168 completed. Total rows saved: 117682
# Processing batch 169 (168000 to 169000 IDs)... Attempt 1
# Batch 169 returned 672 rows.
# Batch 169 completed. Total rows saved: 118354
# Processing batch 170 (169000 to 170000 IDs)... Attempt 1
# Batch 170 returned 681 rows.
# Batch 170 completed. Total rows saved: 119035
# Processing batch 171 (170000 to 171000 IDs)... Attempt 1
# Batch 171 returned 679 rows.
# Batch 171 completed. Total rows saved: 119714
# Processing batch 172 (171000 to 172000 IDs)... Attempt 1
# Batch 172 returned 676 rows.
# Batch 172 completed. Total rows saved: 120390
# Processing batch 173 (172000 to 173000 IDs)... Attempt 1
# Batch 173 returned 688 rows.
# Batch 173 completed. Total rows saved: 121078
# Processing batch 174 (173000 to 174000 IDs)... Attempt 1
# Batch 174 returned 673 rows.
# Batch 174 completed. Total rows saved: 121751
# Processing batch 175 (174000 to 175000 IDs)... Attempt 1
# Batch 175 returned 720 rows.
# Batch 175 completed. Total rows saved: 122471
# Processing batch 176 (175000 to 176000 IDs)... Attempt 1
# Batch 176 returned 702 rows.
# Batch 176 completed. Total rows saved: 123173
# Processing batch 177 (176000 to 177000 IDs)... Attempt 1
# Batch 177 returned 698 rows.
# Batch 177 completed. Total rows saved: 123871
# Processing batch 178 (177000 to 178000 IDs)... Attempt 1
# Batch 178 returned 692 rows.
# Batch 178 completed. Total rows saved: 124563
# Processing batch 179 (178000 to 179000 IDs)... Attempt 1
# Batch 179 returned 698 rows.
# Batch 179 completed. Total rows saved: 125261
# Processing batch 180 (179000 to 180000 IDs)... Attempt 1
# Batch 180 returned 690 rows.
# Batch 180 completed. Total rows saved: 125951
# Processing batch 181 (180000 to 181000 IDs)... Attempt 1
# Batch 181 returned 672 rows.
# Batch 181 completed. Total rows saved: 126623
# Processing batch 182 (181000 to 182000 IDs)... Attempt 1
# Batch 182 returned 710 rows.
# Batch 182 completed. Total rows saved: 127333
# Processing batch 183 (182000 to 183000 IDs)... Attempt 1
# Batch 183 returned 575 rows.
# Batch 183 completed. Total rows saved: 127908
# Processing batch 184 (183000 to 184000 IDs)... Attempt 1
# Batch 184 returned 61 rows.
# Batch 184 completed. Total rows saved: 127969
# Processing batch 185 (184000 to 185000 IDs)... Attempt 1
# Batch 185 returned 168 rows.
# Batch 185 completed. Total rows saved: 128137
# Processing batch 186 (185000 to 186000 IDs)... Attempt 1
# Batch 186 returned 165 rows.
# Batch 186 completed. Total rows saved: 128302
# Processing batch 187 (186000 to 187000 IDs)... Attempt 1
# Batch 187 returned 268 rows.
# Batch 187 completed. Total rows saved: 128570
# Processing batch 188 (187000 to 188000 IDs)... Attempt 1
# Batch 188 returned 165 rows.
# Batch 188 completed. Total rows saved: 128735
# Processing batch 189 (188000 to 189000 IDs)... Attempt 1
# Batch 189 returned 95 rows.
# Batch 189 completed. Total rows saved: 128830
# Processing batch 190 (189000 to 190000 IDs)... Attempt 1
# Batch 190 returned 154 rows.
# Batch 190 completed. Total rows saved: 128984
# Processing batch 191 (190000 to 191000 IDs)... Attempt 1
# Batch 191 returned 114 rows.
# Batch 191 completed. Total rows saved: 129098
# Processing batch 192 (191000 to 192000 IDs)... Attempt 1
# Batch 192 returned 148 rows.
# Batch 192 completed. Total rows saved: 129246
# Processing batch 193 (192000 to 193000 IDs)... Attempt 1
# Batch 193 returned 128 rows.
# Batch 193 completed. Total rows saved: 129374
# Processing batch 194 (193000 to 194000 IDs)... Attempt 1
# Batch 194 returned 109 rows.
# Batch 194 completed. Total rows saved: 129483
# Processing batch 195 (194000 to 195000 IDs)... Attempt 1
# Batch 195 returned 117 rows.
# Batch 195 completed. Total rows saved: 129600
# Processing batch 196 (195000 to 196000 IDs)... Attempt 1
# Error processing batch 195000 to 196000: [Errno 54] Connection reset by peer
# Processing batch 196 (195000 to 196000 IDs)... Attempt 2
# Batch 196 returned 126 rows.
# Batch 196 completed. Total rows saved: 129726
# Processing batch 197 (196000 to 197000 IDs)... Attempt 1
# Batch 197 returned 117 rows.
# Batch 197 completed. Total rows saved: 129843
# Processing batch 198 (197000 to 198000 IDs)... Attempt 1
# Batch 198 returned 93 rows.
# Batch 198 completed. Total rows saved: 129936
# Processing batch 199 (198000 to 199000 IDs)... Attempt 1
# Batch 199 returned 97 rows.
# Batch 199 completed. Total rows saved: 130033
# Processing batch 200 (199000 to 200000 IDs)... Attempt 1
# Batch 200 returned 119 rows.
# Batch 200 completed. Total rows saved: 130152
# Processing batch 201 (200000 to 201000 IDs)... Attempt 1
# Batch 201 returned 88 rows.
# Batch 201 completed. Total rows saved: 130240
# Processing batch 202 (201000 to 202000 IDs)... Attempt 1
# Batch 202 returned 94 rows.
# Batch 202 completed. Total rows saved: 130334
# Processing batch 203 (202000 to 203000 IDs)... Attempt 1
# Batch 203 returned 105 rows.
# Batch 203 completed. Total rows saved: 130439
# Processing batch 204 (203000 to 204000 IDs)... Attempt 1
# Batch 204 returned 93 rows.
# Batch 204 completed. Total rows saved: 130532
# Processing batch 205 (204000 to 205000 IDs)... Attempt 1
# Batch 205 returned 97 rows.
# Batch 205 completed. Total rows saved: 130629
# Processing batch 206 (205000 to 206000 IDs)... Attempt 1
# Error processing batch 205000 to 206000: [Errno 54] Connection reset by peer
# Processing batch 206 (205000 to 206000 IDs)... Attempt 2
# Batch 206 returned 105 rows.
# Batch 206 completed. Total rows saved: 130734
# Processing batch 207 (206000 to 207000 IDs)... Attempt 1
# Error processing batch 206000 to 207000: [Errno 54] Connection reset by peer
# Processing batch 207 (206000 to 207000 IDs)... Attempt 2
# Batch 207 returned 100 rows.
# Batch 207 completed. Total rows saved: 130834
# Processing batch 208 (207000 to 208000 IDs)... Attempt 1
# Batch 208 returned 88 rows.
# Batch 208 completed. Total rows saved: 130922
# Processing batch 209 (208000 to 209000 IDs)... Attempt 1
# Batch 209 returned 104 rows.
# Batch 209 completed. Total rows saved: 131026
# Processing batch 210 (209000 to 210000 IDs)... Attempt 1
# Batch 210 returned 89 rows.
# Batch 210 completed. Total rows saved: 131115
# Processing batch 211 (210000 to 211000 IDs)... Attempt 1
# Batch 211 returned 101 rows.
# Batch 211 completed. Total rows saved: 131216
# Processing batch 212 (211000 to 212000 IDs)... Attempt 1
# Batch 212 returned 81 rows.
# Batch 212 completed. Total rows saved: 131297
# Processing batch 213 (212000 to 213000 IDs)... Attempt 1
# Batch 213 returned 22 rows.
# Batch 213 completed. Total rows saved: 131319
# Processing batch 214 (213000 to 214000 IDs)... Attempt 1
# Batch 214 returned 8 rows.
# Batch 214 completed. Total rows saved: 131327
# Processing batch 215 (214000 to 215000 IDs)... Attempt 1
# Batch 215 returned 16 rows.
# Batch 215 completed. Total rows saved: 131343
# Processing batch 216 (215000 to 216000 IDs)... Attempt 1
# Batch 216 returned 15 rows.
# Batch 216 completed. Total rows saved: 131358
# Processing batch 217 (216000 to 217000 IDs)... Attempt 1
# Batch 217 returned 7 rows.
# Batch 217 completed. Total rows saved: 131365
# Processing batch 218 (217000 to 218000 IDs)... Attempt 1
# Batch 218 returned 1 rows.
# Batch 218 completed. Total rows saved: 131366
# Processing batch 219 (218000 to 219000 IDs)... Attempt 1
# Batch 219 returned 61 rows.
# Batch 219 completed. Total rows saved: 131427
# Processing batch 220 (219000 to 220000 IDs)... Attempt 1
# Batch 220 returned 0 rows.
# Batch 220 completed. Total rows saved: 131427
# Processing batch 221 (220000 to 221000 IDs)... Attempt 1
# Batch 221 returned 9 rows.
# Batch 221 completed. Total rows saved: 131436
# Processing batch 222 (221000 to 222000 IDs)... Attempt 1
# Batch 222 returned 0 rows.
# Batch 222 completed. Total rows saved: 131436
# Processing batch 223 (222000 to 223000 IDs)... Attempt 1
# Batch 223 returned 1 rows.
# Batch 223 completed. Total rows saved: 131437
# Processing batch 224 (223000 to 224000 IDs)... Attempt 1
# Batch 224 returned 0 rows.
# Batch 224 completed. Total rows saved: 131437
# Processing batch 225 (224000 to 225000 IDs)... Attempt 1
# Batch 225 returned 0 rows.
# Batch 225 completed. Total rows saved: 131437
# Processing batch 226 (225000 to 226000 IDs)... Attempt 1
# Batch 226 returned 0 rows.
# Batch 226 completed. Total rows saved: 131437
# Processing batch 227 (226000 to 227000 IDs)... Attempt 1
# Batch 227 returned 0 rows.
# Batch 227 completed. Total rows saved: 131437
# Processing batch 228 (227000 to 228000 IDs)... Attempt 1
# Batch 228 returned 0 rows.
# Batch 228 completed. Total rows saved: 131437
# Processing batch 229 (228000 to 229000 IDs)... Attempt 1
# Batch 229 returned 0 rows.
# Batch 229 completed. Total rows saved: 131437
# Processing batch 230 (229000 to 230000 IDs)... Attempt 1
# Batch 230 returned 0 rows.
# Batch 230 completed. Total rows saved: 131437
# Processing batch 231 (230000 to 231000 IDs)... Attempt 1
# Batch 231 returned 0 rows.
# Batch 231 completed. Total rows saved: 131437
# Processing batch 232 (231000 to 232000 IDs)... Attempt 1
# Batch 232 returned 0 rows.
# Batch 232 completed. Total rows saved: 131437
# Processing batch 233 (232000 to 233000 IDs)... Attempt 1
# Batch 233 returned 0 rows.
# Batch 233 completed. Total rows saved: 131437
# Processing batch 234 (233000 to 234000 IDs)... Attempt 1
# Batch 234 returned 0 rows.
# Batch 234 completed. Total rows saved: 131437
# Processing batch 235 (234000 to 235000 IDs)... Attempt 1
# Batch 235 returned 0 rows.
# Batch 235 completed. Total rows saved: 131437
# Processing batch 236 (235000 to 236000 IDs)... Attempt 1
# Batch 236 returned 0 rows.
# Batch 236 completed. Total rows saved: 131437
# Processing batch 237 (236000 to 237000 IDs)... Attempt 1
# Batch 237 returned 0 rows.
# Batch 237 completed. Total rows saved: 131437
# Processing batch 238 (237000 to 238000 IDs)... Attempt 1
# Batch 238 returned 0 rows.
# Batch 238 completed. Total rows saved: 131437
# Processing batch 239 (238000 to 239000 IDs)... Attempt 1
# Batch 239 returned 0 rows.
# Batch 239 completed. Total rows saved: 131437
# Processing batch 240 (239000 to 240000 IDs)... Attempt 1
# Batch 240 returned 0 rows.
# Batch 240 completed. Total rows saved: 131437
# Processing batch 241 (240000 to 241000 IDs)... Attempt 1
# Batch 241 returned 6 rows.
# Batch 241 completed. Total rows saved: 131443
# Processing batch 242 (241000 to 242000 IDs)... Attempt 1
# Batch 242 returned 34 rows.
# Batch 242 completed. Total rows saved: 131477
# Processing batch 243 (242000 to 243000 IDs)... Attempt 1
# Batch 243 returned 0 rows.
# Batch 243 completed. Total rows saved: 131477
# Processing batch 244 (243000 to 244000 IDs)... Attempt 1
# Batch 244 returned 47 rows.
# Batch 244 completed. Total rows saved: 131524
# Processing batch 245 (244000 to 245000 IDs)... Attempt 1
# Batch 245 returned 0 rows.
# Batch 245 completed. Total rows saved: 131524
# Processing batch 246 (245000 to 246000 IDs)... Attempt 1
# Batch 246 returned 25 rows.
# Batch 246 completed. Total rows saved: 131549
# Processing batch 247 (246000 to 247000 IDs)... Attempt 1
# Batch 247 returned 29 rows.
# Batch 247 completed. Total rows saved: 131578
# Processing batch 248 (247000 to 248000 IDs)... Attempt 1
# Batch 248 returned 0 rows.
# Batch 248 completed. Total rows saved: 131578
# Processing batch 249 (248000 to 249000 IDs)... Attempt 1
# Batch 249 returned 0 rows.
# Batch 249 completed. Total rows saved: 131578
# Processing batch 250 (249000 to 250000 IDs)... Attempt 1
# Batch 250 returned 0 rows.
# Batch 250 completed. Total rows saved: 131578
# Processing batch 251 (250000 to 251000 IDs)... Attempt 1
# Batch 251 returned 39 rows.
# Batch 251 completed. Total rows saved: 131617
# Processing batch 252 (251000 to 252000 IDs)... Attempt 1
# Error processing batch 251000 to 252000: [Errno 54] Connection reset by peer
# Processing batch 252 (251000 to 252000 IDs)... Attempt 2
# Batch 252 returned 18 rows.
# Batch 252 completed. Total rows saved: 131635
# Processing batch 253 (252000 to 253000 IDs)... Attempt 1
# Batch 253 returned 1 rows.
# Batch 253 completed. Total rows saved: 131636
# Processing batch 254 (253000 to 254000 IDs)... Attempt 1
# Batch 254 returned 0 rows.
# Batch 254 completed. Total rows saved: 131636
# Processing batch 255 (254000 to 255000 IDs)... Attempt 1
# Batch 255 returned 0 rows.
# Batch 255 completed. Total rows saved: 131636
# Processing batch 256 (255000 to 256000 IDs)... Attempt 1
# Batch 256 returned 0 rows.
# Batch 256 completed. Total rows saved: 131636
# Processing batch 257 (256000 to 257000 IDs)... Attempt 1
# Batch 257 returned 0 rows.
# Batch 257 completed. Total rows saved: 131636
# Processing batch 258 (257000 to 258000 IDs)... Attempt 1
# Batch 258 returned 0 rows.
# Batch 258 completed. Total rows saved: 131636
# Processing batch 259 (258000 to 259000 IDs)... Attempt 1
# Batch 259 returned 0 rows.
# Batch 259 completed. Total rows saved: 131636
# Processing batch 260 (259000 to 260000 IDs)... Attempt 1
# Batch 260 returned 0 rows.
# Batch 260 completed. Total rows saved: 131636
# Processing batch 261 (260000 to 261000 IDs)... Attempt 1
# Batch 261 returned 0 rows.
# Batch 261 completed. Total rows saved: 131636
# Processing batch 262 (261000 to 262000 IDs)... Attempt 1
# Batch 262 returned 0 rows.
# Batch 262 completed. Total rows saved: 131636
# Processing batch 263 (262000 to 263000 IDs)... Attempt 1
# Batch 263 returned 0 rows.
# Batch 263 completed. Total rows saved: 131636
# Processing batch 264 (263000 to 264000 IDs)... Attempt 1
# Batch 264 returned 0 rows.
# Batch 264 completed. Total rows saved: 131636
# Processing batch 265 (264000 to 265000 IDs)... Attempt 1
# Batch 265 returned 0 rows.
# Batch 265 completed. Total rows saved: 131636
# Processing batch 266 (265000 to 266000 IDs)... Attempt 1
# Batch 266 returned 0 rows.
# Batch 266 completed. Total rows saved: 131636
# Processing batch 267 (266000 to 267000 IDs)... Attempt 1
# Batch 267 returned 1 rows.
# Batch 267 completed. Total rows saved: 131637
# Processing batch 268 (267000 to 268000 IDs)... Attempt 1
# Batch 268 returned 0 rows.
# Batch 268 completed. Total rows saved: 131637
# Processing batch 269 (268000 to 269000 IDs)... Attempt 1
# Batch 269 returned 0 rows.
# Batch 269 completed. Total rows saved: 131637
# Processing batch 270 (269000 to 270000 IDs)... Attempt 1
# Batch 270 returned 0 rows.
# Batch 270 completed. Total rows saved: 131637
# Processing batch 271 (270000 to 271000 IDs)... Attempt 1
# Batch 271 returned 0 rows.
# Batch 271 completed. Total rows saved: 131637
# Processing batch 272 (271000 to 272000 IDs)... Attempt 1
# Batch 272 returned 0 rows.
# Batch 272 completed. Total rows saved: 131637
# Processing batch 273 (272000 to 273000 IDs)... Attempt 1
# Batch 273 returned 0 rows.
# Batch 273 completed. Total rows saved: 131637
# Processing batch 274 (273000 to 274000 IDs)... Attempt 1
# Batch 274 returned 0 rows.
# Batch 274 completed. Total rows saved: 131637
# Processing batch 275 (274000 to 275000 IDs)... Attempt 1
# Batch 275 returned 0 rows.
# Batch 275 completed. Total rows saved: 131637
# Processing batch 276 (275000 to 276000 IDs)... Attempt 1
# Batch 276 returned 0 rows.
# Batch 276 completed. Total rows saved: 131637
# Processing batch 277 (276000 to 277000 IDs)... Attempt 1
# Batch 277 returned 0 rows.
# Batch 277 completed. Total rows saved: 131637
# Processing batch 278 (277000 to 278000 IDs)... Attempt 1
# Batch 278 returned 0 rows.
# Batch 278 completed. Total rows saved: 131637
# Processing batch 279 (278000 to 279000 IDs)... Attempt 1
# Batch 279 returned 0 rows.
# Batch 279 completed. Total rows saved: 131637
# Processing batch 280 (279000 to 280000 IDs)... Attempt 1
# Batch 280 returned 0 rows.
# Batch 280 completed. Total rows saved: 131637
# Processing batch 281 (280000 to 281000 IDs)... Attempt 1
# Batch 281 returned 1 rows.
# Batch 281 completed. Total rows saved: 131638
# Processing batch 282 (281000 to 282000 IDs)... Attempt 1
# Batch 282 returned 0 rows.
# Batch 282 completed. Total rows saved: 131638
# Processing batch 283 (282000 to 283000 IDs)... Attempt 1
# Batch 283 returned 53 rows.
# Batch 283 completed. Total rows saved: 131691
# Processing batch 284 (283000 to 284000 IDs)... Attempt 1
# Batch 284 returned 0 rows.
# Batch 284 completed. Total rows saved: 131691
# Processing batch 285 (284000 to 285000 IDs)... Attempt 1
# Batch 285 returned 0 rows.
# Batch 285 completed. Total rows saved: 131691
# Processing batch 286 (285000 to 286000 IDs)... Attempt 1
# Batch 286 returned 45 rows.
# Batch 286 completed. Total rows saved: 131736
# Processing batch 287 (286000 to 287000 IDs)... Attempt 1
# Batch 287 returned 39 rows.
# Batch 287 completed. Total rows saved: 131775
# Processing batch 288 (287000 to 288000 IDs)... Attempt 1
# Batch 288 returned 71 rows.
# Batch 288 completed. Total rows saved: 131846
# Processing batch 289 (288000 to 289000 IDs)... Attempt 1
# Batch 289 returned 93 rows.
# Batch 289 completed. Total rows saved: 131939
# Processing batch 290 (289000 to 290000 IDs)... Attempt 1
# Batch 290 returned 474 rows.
# Batch 290 completed. Total rows saved: 132413
# Processing batch 291 (290000 to 291000 IDs)... Attempt 1
# Batch 291 returned 558 rows.
# Batch 291 completed. Total rows saved: 132971
# Processing batch 292 (291000 to 292000 IDs)... Attempt 1
# Batch 292 returned 327 rows.
# Batch 292 completed. Total rows saved: 133298
# Processing batch 293 (292000 to 293000 IDs)... Attempt 1
# Batch 293 returned 287 rows.
# Batch 293 completed. Total rows saved: 133585
# Processing batch 294 (293000 to 294000 IDs)... Attempt 1
# Batch 294 returned 24 rows.
# Batch 294 completed. Total rows saved: 133609
# Processing batch 295 (294000 to 295000 IDs)... Attempt 1
# Batch 295 returned 36 rows.
# Batch 295 completed. Total rows saved: 133645
# Processing batch 296 (295000 to 296000 IDs)... Attempt 1
# Batch 296 returned 188 rows.
# Batch 296 completed. Total rows saved: 133833
# Reprocessing failed batches...
# All processing completed.

# %% [markdown]
# Now we will move on with downloading the spectra.
